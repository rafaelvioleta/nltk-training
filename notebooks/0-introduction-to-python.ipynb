# %%
name = input('What is your name?')
print('Hello', name)

subjects = ['math', 'computer science', 'filipino', 'economics']

print('subjects[-1] = ', subjects[-1])

def function123(yam):
  print(yam)
  
function123(subjects)
# Out:
# What is your name?jed
# Hello jed
# subjects[-1] =  economics
# ['math', 'computer science', 'filipino', 'economics']
